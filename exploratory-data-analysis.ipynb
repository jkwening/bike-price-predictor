# %%
# modules needed for inline matplotlib and seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()  # set plotting style to seaborn

# %%
# modules
import pandas as pd

# sklearn modules
from sklearn.model_selection import StratifiedShuffleSplit

# %% [markdown]
# ## Load Data File

# %%
munged_df = pd.read_csv('data/munged/bikes_2019-03-24.csv')
munged_df.head()
# Out:
#   bike_type      brand    price frame_material  model_year brake_type  \
# 0      road  Pinarello  12000.0         carbon      2018.0        rim
# 1      road  Pinarello  10000.0         carbon         NaN  hydraulic
# 2      road     Factor   9999.0         carbon      2018.0  hydraulic
# 3      road     Factor   8750.0         carbon         NaN        rim
# 4      road     Factor   8999.0         carbon      2018.0        rim
#
#   fork_material handlebar_material       fd_groupset       rd_groupset  \
# 0        carbon             carbon     sram red etap     sram red etap
# 1        carbon             carbon  shimano dura-ace  shimano dura-ace
# 2        carbon                NaN     sram red etap     sram red etap
# 3        carbon                NaN     sram red etap     sram red etap
# 4        carbon             carbon     sram red etap     sram red etap
#
#   cassette_groupset crankset_material crankset_groupset seatpost_material  \
# 0          sram red               NaN          sram red               NaN
# 1  shimano dura-ace               NaN  shimano dura-ace               NaN
# 2        sram force               NaN          sram red               NaN
# 3          sram red               NaN          sram red               NaN
# 4          sram red               NaN          sram red               NaN
#
#      chain_groupset  shifter_groupset
# 0          sram red     sram red etap
# 1  shimano dura-ace  shimano dura-ace
# 2          sram red     sram red etap
# 3          sram red     sram red etap
# 4          sram red     sram red etap

# %% [markdown]
# ### Quick Glance
# Let's take a quick glance to see what we're working with to get a better sense of what we're working with.
#
# #### Info
# * There are 2194 samples
# * 16 columns of which **price** and **model_year** are numeric data, everthing else is categorical.
# * **bike_type**, **brand**, **price**, and **brake_type** are only fields without missing data.
# * Many of the fields have missing values; need to determine how to best handle this.

# %%
munged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2194 entries, 0 to 2193
# Data columns (total 16 columns):
# bike_type             2194 non-null object
# brand                 2194 non-null object
# price                 2194 non-null float64
# frame_material        1936 non-null object
# model_year            1582 non-null float64
# brake_type            2194 non-null object
# fork_material         1076 non-null object
# handlebar_material    1150 non-null object
# fd_groupset           642 non-null object
# rd_groupset           1360 non-null object
# cassette_groupset     1503 non-null object
# crankset_material     639 non-null object
# crankset_groupset     994 non-null object
# seatpost_material     1024 non-null object
# chain_groupset        902 non-null object
# shifter_groupset      1113 non-null object
# dtypes: float64(2), object(14)
# memory usage: 274.3+ KB

# %% [markdown]
# #### Numerical
# ##### Price
# * we have values less than 0, we should look into these and possibly drop before test split
# * there seems to be few very expensive bike samples in the dataset; definitely want to ensure they're distributed in both train and test sets
#
# ##### Model Year
# * range from 2013 to 2020
# * looks like most bike sample are 2019 model year, which makes sense since data was collected in 2018-2019 season

# %%
munged_df.model_year.mode()
# Out:
# 0    2019.0
# dtype: float64

# %%
munged_df.describe()
# Out:
#               price   model_year
# count   2194.000000  1582.000000
# mean    2250.573801  2018.257901
# std     2151.609557     0.847206
# min       -1.000000  2013.000000
# 25%      535.992500  2018.000000
# 50%     1499.990000  2018.000000
# 75%     3399.980000  2019.000000
# max    12519.990000  2020.000000

# %% [markdown]
# ### Data Cleaning
# From quick glance of the dataset, it looks like it needs a little more data cleaning before we can proceed with test set hold out. Tasks:
# 1. We have prices less than zero, we should drop samples with bike prices less than a certain threshold
# 2. Remove samples that missing values for all fields except "brand", "price", "brake_type" which have no missing values.
# 3. Look at **bike_type** field and determine if we need to drop any specific values. We care primarily about adult bikes.

# %%
# Identify samples with empty rows
empty_rows_df = munged_df[(munged_df.frame_material.isnull()) & (munged_df.model_year.isnull())
         & (munged_df.fork_material.isnull()) & (munged_df.handlebar_material.isnull())
         & (munged_df.fd_groupset.isnull()) & (munged_df.rd_groupset.isnull())
         & (munged_df.cassette_groupset.isnull()) & (munged_df.crankset_material.isnull())
         & (munged_df.crankset_groupset.isnull()) & (munged_df.seatpost_material.isnull())
         & (munged_df.chain_groupset.isnull()) & (munged_df.shifter_groupset.isnull())]
empty_rows_df.head()
# Out:
#      bike_type   brand  price frame_material  model_year brake_type  \
# 215  childrens      SE  169.0            NaN         NaN      other
# 222  childrens      SE  179.0            NaN         NaN      other
# 256  childrens      SE  159.0            NaN         NaN      other
# 433  childrens  Weehoo  449.0            NaN         NaN      other
# 434  childrens  Weehoo  199.0            NaN         NaN      other
#
#     fork_material handlebar_material fd_groupset rd_groupset  \
# 215           NaN                NaN         NaN         NaN
# 222           NaN                NaN         NaN         NaN
# 256           NaN                NaN         NaN         NaN
# 433           NaN                NaN         NaN         NaN
# 434           NaN                NaN         NaN         NaN
#
#     cassette_groupset crankset_material crankset_groupset seatpost_material  \
# 215               NaN               NaN               NaN               NaN
# 222               NaN               NaN               NaN               NaN
# 256               NaN               NaN               NaN               NaN
# 433               NaN               NaN               NaN               NaN
# 434               NaN               NaN               NaN               NaN
#
#     chain_groupset shifter_groupset
# 215            NaN              NaN
# 222            NaN              NaN
# 256            NaN              NaN
# 433            NaN              NaN
# 434            NaN              NaN

# %%
# Identify bikes with prices less than 100
low_price_df = munged_df[munged_df.price < 100]
low_price_df.head()
# Out:
#     bike_type     brand  price frame_material  model_year brake_type  \
# 95       road   Bianchi   -1.0         carbon      2018.0        rim
# 666  mountain     Niner   -1.0         carbon      2017.0  hydraulic
# 667  mountain     Pivot   -1.0         carbon      2018.0  hydraulic
# 668  mountain     Pivot   -1.0         carbon      2017.0  hydraulic
# 715  mountain  Borealis   -1.0         carbon      2018.0  hydraulic
#
#     fork_material handlebar_material          fd_groupset  \
# 95         carbon                NaN  shimano ultegra di2
# 666           NaN                NaN                  NaN
# 667           NaN             carbon                  NaN
# 668           NaN             carbon                  NaN
# 715           NaN              alloy                  NaN
#
#              rd_groupset cassette_groupset crankset_material  \
# 95   shimano ultegra di2   shimano ultegra               NaN
# 666     shimano deore xt  shimano deore xt               NaN
# 667          shimano xtr  shimano deore xt               NaN
# 668       sram xO1 eagle    sram xO1 eagle               NaN
# 715       sram xO1 eagle     sram gx eagle               NaN
#
#     crankset_groupset seatpost_material    chain_groupset     shifter_groupset
# 95    shimano ultegra               NaN               NaN  shimano ultegra di2
# 666  shimano deore xt               NaN  shimano deore xt     shimano deore xt
# 667         race face               NaN               NaN     shimano deore xt
# 668    sram xO1 eagle            carbon               NaN       sram xO1 eagle
# 715           sram gx             alloy           sram x1              sram gx

# %%
# Identify bike_type values that should be dropped
munged_df.bike_type.value_counts()
# Out:
# mountain       781
# road           441
# childrens      242
# urban          236
# bmx            132
# ebike          129
# cyclocross      71
# comfort         46
# hybrid          40
# touring         30
# commuter        23
# folding         12
# triathlon        4
# track            3
# cargo            3
# singlespeed      1
# Name: bike_type, dtype: int64

# %%
# Drop children's bike and focus on adult bikes only
children_df = munged_df[munged_df.bike_type == 'childrens']
children_df.head()
# Out:
#      bike_type brand   price frame_material  model_year   brake_type  \
# 145  childrens  Fuji  159.99          alloy      2019.0      coaster
# 198  childrens  Fuji  344.99          alloy      2019.0  linear_pull
# 207  childrens  Fuji  424.99          alloy      2019.0   mechanical
# 213  childrens  Fuji  239.99          alloy         NaN  linear_pull
# 215  childrens    SE  169.00            NaN         NaN        other
#
#     fork_material handlebar_material      fd_groupset      rd_groupset  \
# 145         steel              steel              NaN              NaN
# 198           NaN              steel  shimano tourney    shimano acera
# 207           NaN              alloy              NaN    shimano acera
# 213           NaN              steel              NaN  shimano tourney
# 215           NaN                NaN              NaN              NaN
#
#     cassette_groupset crankset_material crankset_groupset seatpost_material  \
# 145               NaN             steel               NaN             alloy
# 198     shimano altus               NaN               NaN             steel
# 207   shimano tourney               NaN               NaN             alloy
# 213      single speed               NaN               NaN             steel
# 215               NaN               NaN               NaN               NaN
#
#     chain_groupset shifter_groupset
# 145            NaN              NaN
# 198            NaN  shimano tourney
# 207            NaN    shimano altus
# 213            NaN  shimano tourney
# 215            NaN              NaN

# %%
# Create dataframe without dropped rows
drop_list = empty_rows_df.index.tolist() + low_price_df.index.tolist() + children_df.index.tolist()
drop_list = set(drop_list)  # remove dupes
drop_count = len(drop_list)
print(f'There are {drop_count} samples to be dropped.')
print(f'There should be {len(munged_df) - drop_count} samles left afterwards.')
data_df = munged_df.drop(drop_list)
print(f'There are now {len(data_df)} samples remaining.')
# Out:
# There are 274 samples to be dropped.
# There should be 1920 samles left afterwards.
# There are now 1920 samples remaining.

# %%
data_df.bike_type.value_counts()
# Out:
# mountain       769
# road           438
# urban          234
# ebike          128
# bmx            120
# cyclocross      71
# comfort         46
# hybrid          39
# touring         30
# commuter        23
# folding         12
# triathlon        4
# track            3
# cargo            2
# singlespeed      1
# Name: bike_type, dtype: int64

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1920 entries, 0 to 2193
# Data columns (total 16 columns):
# bike_type             1920 non-null object
# brand                 1920 non-null object
# price                 1920 non-null float64
# frame_material        1765 non-null object
# model_year            1441 non-null float64
# brake_type            1920 non-null object
# fork_material         966 non-null object
# handlebar_material    1032 non-null object
# fd_groupset           621 non-null object
# rd_groupset           1288 non-null object
# cassette_groupset     1430 non-null object
# crankset_material     563 non-null object
# crankset_groupset     980 non-null object
# seatpost_material     928 non-null object
# chain_groupset        886 non-null object
# shifter_groupset      1062 non-null object
# dtypes: float64(2), object(14)
# memory usage: 255.0+ KB

# %%
data_df.describe()
# Out:
#               price   model_year
# count   1920.000000  1441.000000
# mean    2520.567760  2018.252602
# std     2163.364683     0.845763
# min      159.990000  2013.000000
# 25%      724.990000  2018.000000
# 50%     1894.500000  2018.000000
# 75%     3599.990000  2019.000000
# max    12519.990000  2020.000000

# %% [markdown]
# ## Train Test Split
# Implement "stratified" split for this regression data. By doing so, the hope is to get a more reliable (lower bias and variance) estimate of model performance. Using regular random split on the dataset is likely to naturally introduce bias into the data or unintentionally exclude data points, and thus affect model performance. Using stratification during model selection produces better results because the validation set(s) more accurately represent the task we need to solve. If one class is hard to predict, we won’t have more of them (artificially hindering the performance metric) or less (assisting performance) if we use stratification.
#
# #### Sorted Stratification
# Since this a regression task and not classification, we need a method to define the "classification" sets of the data so we can ensure similar distribution of the target variable in both the train and test sets. The following approach will be used to achieve this:
# 1. Sort the samples on the target variable
# 2. Categorize samples into *k* partitions (or "classes") depending on test size needed
# 3. Utilize sklearn's "StratifiedShuffleSplit" to generate tran vs test split
#
# Alternative approach is to categorize samples by **bike_type** to ensure similar distribution of bike types between train and test sets. Categorizing by target variable is most likely the best since that is what we're predicting for. The latter might introduce other biases that we're unaware.

# %%
# Set random state for reproducibility purposes
RAND_STATE = 42

# %%
# We can simplify steps 1 and 2 by help of pandas.qcut method
price_cats = pd.qcut(x=data_df.price, q=10, labels=range(10))
price_cats.head()
# Out:
# 0    9
# 1    9
# 2    9
# 3    9
# 4    9
# Name: price, dtype: category
# Categories (10, int64): [0 < 1 < 2 < 3 ... 6 < 7 < 8 < 9]

# %%
# Generate shuffled train and test indices
train_idx, test_idx = next(
    StratifiedShuffleSplit(n_splits=1, test_size=0.20, random_state=RAND_STATE).split(
        X=price_cats, y=price_cats
    )
)
print(f'Num train samples: {len(train_idx)}\nNum test samples: {len(test_idx)}')
# Out:
# Num train samples: 1536
# Num test samples: 384

# %%
# Get train and test datasets
train_df = data_df.iloc[train_idx].copy()
test_df = data_df.iloc[test_idx].copy()  # Hold-out set

# Verify dimensions
print(f'train shape: {train_df.shape}\ntest shape: {test_df.shape}')
# Out:
# train shape: (1536, 16)
# test shape: (384, 16)

# %% [markdown]
# ## Train Data Exploration and Feature Engineering
# The data has many categorical fields. The first step is see how we can transform them into useful numerical fields. This will involving some one-hot encoding and identifying rankable values.
#
# **price** and **model_year** are already numerical. Price is the target variable, so we won't directly touch this since we don't want to include it as a feature else we will be indirectly including what we want to predict as feature.
#
# Let's look at each of the remaining categorical fields to see how best to utilize or whether to just drop them. Model year has some missing valaues so we will need to decide how we want to handle those missing values.

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1536 entries, 1687 to 1902
# Data columns (total 16 columns):
# bike_type             1536 non-null object
# brand                 1536 non-null object
# price                 1536 non-null float64
# frame_material        1418 non-null object
# model_year            1146 non-null float64
# brake_type            1536 non-null object
# fork_material         756 non-null object
# handlebar_material    836 non-null object
# fd_groupset           477 non-null object
# rd_groupset           1027 non-null object
# cassette_groupset     1149 non-null object
# crankset_material     460 non-null object
# crankset_groupset     795 non-null object
# seatpost_material     741 non-null object
# chain_groupset        717 non-null object
# shifter_groupset      857 non-null object
# dtypes: float64(2), object(14)
# memory usage: 204.0+ KB

# %% [markdown]
# #### Frame Material
# There are 1418 non-null samples. Looking at value counts, we see majority of frame material are either carbon or aluminium/alloy material. This is typical of what you would expect, majority of bikes this day are primarily aluminium or some alloy and for top-end there's a high demand for carbon due to its lightness and stiffness. The average price per frame material confirms this. Carbon frame bikes are considerably more expensive than aluminium or alloy frame bikes. Titanium also seems to garner higher price but we only have two samples represented in train dataset so we should consider trying to get more data for such bikes.
#
# Since carbon and titanium seem to have a strong relationship to price, the best approach for this categorical data is to implement one-hot encoding for carbon frame material. The same will be done for titanium in preparation for when more data is collected. After doing some further research, titanium seems to be an upcoming frame material for similar reasons as carbon but less fragile.

# %%
print(train_df.frame_material.value_counts())
grouped = train_df.groupby('frame_material')
grouped['price'].mean()
# Out:
# carbon      590
# aluminum    454
# alloy       222
# steel        88
# chromoly     62
# titanium      2
# Name: frame_material, dtype: int64
# frame_material
# alloy       1350.845631
# aluminum    1639.982753
# carbon      4240.846712
# chromoly    1002.245161
# steel        777.092727
# titanium    3499.000000
# Name: price, dtype: float64

# %%
train_df['carbon_frame'] = train_df.frame_material.apply(lambda x: 1 if x == 'carbon' else 0)
train_df.carbon_frame.value_counts()
# Out:
# 0    946
# 1    590
# Name: carbon_frame, dtype: int64

# %%
train_df['titanium_frame'] = train_df.frame_material.map(lambda x: 1 if x == 'titanium' else 0)
train_df.titanium_frame.value_counts()
# Out:
# 0    1534
# 1       2
# Name: titanium_frame, dtype: int64

# %% [markdown]
# #### Other Material Categorical Fields
# Except for fork material, we see that carbon material continues to have a strong relationship to price for other material based fields. So we will implement similar one-hot encoding to extract numerical features for these fields.

# %%
print(train_df.handlebar_material.value_counts())
grouped = train_df.groupby('handlebar_material')
grouped['price'].mean()
# Out:
# alloy       565
# carbon      139
# aluminum     73
# steel        41
# chromoly     18
# Name: handlebar_material, dtype: int64
# handlebar_material
# alloy       1951.561398
# aluminum    1734.927260
# carbon      6430.066835
# chromoly     658.993333
# steel        418.381463
# Name: price, dtype: float64

# %%
train_df['carbon_handlebar'] = train_df.handlebar_material.apply(lambda x: 1 if x == 'carbon' else 0)
train_df.carbon_handlebar.value_counts()
# Out:
# 0    1397
# 1     139
# Name: carbon_handlebar, dtype: int64

# %%
print(train_df.crankset_material.value_counts())
grouped = train_df.groupby('crankset_material')
grouped['price'].mean()
# Out:
# alloy       245
# carbon       79
# steel        55
# aluminum     48
# chromoly     33
# Name: crankset_material, dtype: int64
# crankset_material
# alloy       1603.336286
# aluminum    2626.796667
# carbon      6350.193418
# chromoly     461.870000
# steel       1159.007273
# Name: price, dtype: float64

# %%
train_df['carbon_crankset'] = train_df.crankset_material.apply(lambda x: 1 if x == 'carbon' else 0)
train_df.carbon_crankset.value_counts()
# Out:
# 0    1457
# 1      79
# Name: carbon_crankset, dtype: int64

# %%
print(train_df.seatpost_material.value_counts())
grouped = train_df.groupby('seatpost_material')
grouped['price'].mean()
# Out:
# alloy       517
# carbon      156
# aluminum     48
# steel        20
# Name: seatpost_material, dtype: int64
# seatpost_material
# alloy       1299.749729
# aluminum    1622.093125
# carbon      4037.964103
# steel        476.789500
# Name: price, dtype: float64

# %%
train_df['carbon_seatpost'] = train_df.seatpost_material.apply(lambda x: 1 if x == 'carbon' else 0)
train_df.carbon_seatpost.value_counts()
# Out:
# 0    1380
# 1     156
# Name: carbon_seatpost, dtype: int64

# %% [markdown]
# Alloy, aluminium, and carbon fork have relatively same average price. Surprisingly, having steel and chromoly fork has strong negative relationship to price. For this, we will implement one-hot encoding for steel and chromoly fork material; or rather one-hot encoding for non-carbon, alloy, aluminium for material.

# %%
print(train_df.fork_material.value_counts())
grouped = train_df.groupby('fork_material')
grouped['price'].mean()
# Out:
# carbon      396
# steel       164
# alloy        73
# chromoly     67
# aluminum     56
# Name: fork_material, dtype: int64
# fork_material
# alloy       2542.837123
# aluminum    2259.267143
# carbon      2783.785833
# chromoly    1011.839104
# steel        847.309939
# Name: price, dtype: float64

# %%
train_df['nonstandard_fork'] = train_df.fork_material.apply(lambda x: 1 if x == 'chromoly' or x == 'steel' else 0)
train_df.nonstandard_fork.value_counts()
# Out:
# 0    1305
# 1     231
# Name: nonstandard_fork, dtype: int64

# %% [markdown]
# #### Brake Type

# %%
print(train_df.brake_type.value_counts())
grouped = train_df.groupby('brake_type')
grouped['price'].mean()
# Out:
# hydraulic      773
# other          298
# mechanical     125
# disc           114
# vbrake          59
# rim             53
# caliper         48
# linear_pull     28
# ubrake          20
# coaster         18
# Name: brake_type, dtype: int64
# brake_type
# caliper        1373.881458
# coaster         384.374444
# disc           2420.468070
# hydraulic      3310.022885
# linear_pull     996.412143
# mechanical     1089.069840
# other          2097.056946
# rim            2780.842264
# ubrake          310.039500
# vbrake          499.992203
# Name: price, dtype: float64

# %%
train_df[(train_df.brake_type == 'disc') | (train_df.brake_type == 'hydraulic') | (train_df.brake_type == 'mechanical')].mean()
# Out:
# price               2935.488913
# model_year          2018.330544
# titanium_frame         0.000000
# carbon_frame           0.443676
# carbon_handlebar       0.113636
# carbon_crankset        0.070158
# carbon_seatpost        0.103755
# nonstandard_fork       0.072134
# dtype: float64

# %%
train_df[train_df.brake_type == 'other'] ### DATA INTEGRITY ISSUES - NEED TO CLEAN UP DATA PIPELINE
# Seem to have framesets in samples and unnecessarily incomplete samples which have actual specs on website
# Out:
#        bike_type          brand    price frame_material  model_year  \
# 2046       ebike    Specialized  3449.99            NaN      2019.0
# 1699    mountain     Santa Cruz  2799.99         carbon      2019.0
# 1825    mountain           Haro   329.99            NaN      2017.0
# 910        track           Fuji   336.99       chromoly      2018.0
# 1535        road    Specialized  4124.99         carbon      2017.0
# 2061         bmx           Haro  1369.99       chromoly      2018.0
# 1616        road    Specialized   679.99       aluminum      2016.0
# 676   cyclocross          Pivot  4499.00         carbon         NaN
# 1890    mountain    Specialized  2499.99            NaN      2019.0
# 2193         bmx           Kink   699.99       chromoly      2019.0
# 1300       urban          Jamis   699.95       chromoly      2017.0
# 2021       urban          Benno  1099.99            NaN      2019.0
# 510     mountain          Niner  2240.00         carbon      2018.0
# 1625       urban           Pure   399.00          steel      2018.0
# 2170         bmx           Haro   799.99       chromoly      2018.0
# 1972         bmx  We The People   419.99            NaN      2019.0
# 1766       urban          Benno   679.99            NaN      2019.0
# 1346       ebike    Specialized  2999.95       aluminum      2017.0
# 1830    mountain     Santa Cruz  3799.99         carbon      2019.0
# 63          road        Bianchi  4500.00         carbon      2018.0
# 2169         bmx           Haro   379.99          steel      2018.0
# 2191         bmx  We The People   769.99            NaN      2019.0
# 571         road        Colnago  2764.83            NaN      2017.0
# 1507        road    Specialized  2499.99         carbon      2019.0
# 1780    mountain     Santa Cruz  5699.99         carbon      2019.0
# 1608       urban           Pure   399.00          steel      2018.0
# 1559        road    Specialized  2299.99            NaN      2017.0
# 1671    mountain     Santa Cruz  2699.99         carbon      2018.0
# 2149         bmx            Fit   439.99            NaN      2019.0
# 295         road           Fuji  6299.97         carbon      2018.0
# ...          ...            ...      ...            ...         ...
# 1891    mountain    Specialized  3750.00            NaN      2019.0
# 1923    mountain    Specialized  3199.99            NaN      2019.0
# 1630        road    Specialized  1699.99         carbon      2015.0
# 181         road           Fuji  1349.97          alloy      2018.0
# 1479        road        Bianchi  3499.99         carbon      2018.0
# 1749    mountain          Pivot  5799.99         carbon      2018.0
# 2190         bmx  We The People   729.00            NaN      2019.0
# 1875       ebike        Haibike  6999.99       aluminum      2019.0
# 67          road         Ridley  4499.00         carbon         NaN
# 1879       urban           Pure   299.00            NaN      2018.0
# 1572       urban    Specialized   899.99            NaN      2017.0
# 301         road        Kestrel  4999.99         carbon      2018.0
# 619     mountain        Juliana  4899.00         carbon         NaN
# 1992         bmx  We The People   489.99            NaN      2019.0
# 672   cyclocross          Niner  3800.00         carbon         NaN
# 2178         bmx        Eastern   369.99            NaN      2019.0
# 1126       urban    Specialized   549.95       aluminum      2017.0
# 1676    mountain     Santa Cruz  2699.99       aluminum      2019.0
# 1874       ebike        Haibike  5799.99       aluminum      2019.0
# 1853    mountain    Specialized  3599.99         carbon      2018.0
# 257        track           Fuji  1079.97          alloy      2018.0
# 1516        road    Specialized  5499.99         carbon      2019.0
# 2080         bmx  We The People   459.99            NaN      2019.0
# 1642        road    Specialized  1399.99       chromoly      2019.0
# 2142         bmx           Haro   269.99          steel      2019.0
# 1835    mountain    Specialized   349.99            NaN      2017.0
# 1263       urban     Cannondale   439.73            NaN      2018.0
# 1951       ebike        Raleigh  2499.99       aluminum      2018.0
# 1308       urban           Pure   429.00          steel      2017.0
# 665     mountain        Alchemy  2999.00         carbon         NaN
#
#      brake_type fork_material handlebar_material      fd_groupset  \
# 2046      other           NaN                NaN              NaN
# 1699      other           NaN                NaN              NaN
# 1825      other           NaN                NaN              NaN
# 910       other      chromoly              alloy              NaN
# 1535      other        carbon              alloy    sram red etap
# 2061      other      chromoly           chromoly              NaN
# 1616      other        carbon              alloy     shimano sora
# 676       other        carbon                NaN  shimano ultegra
# 1890      other           NaN                NaN              NaN
# 2193      other      chromoly                NaN              NaN
# 1300      other      chromoly           aluminum     shimano sora
# 2021      other           NaN                NaN              NaN
# 510       other           NaN                NaN              NaN
# 1625      other         steel           aluminum              NaN
# 2170      other      chromoly              alloy              NaN
# 1972      other           NaN                NaN              NaN
# 1766      other           NaN                NaN              NaN
# 1346      other         alloy              alloy              NaN
# 1830      other           NaN                NaN              NaN
# 63        other        carbon                NaN              NaN
# 2169      other         steel              steel              NaN
# 2191      other           NaN                NaN              NaN
# 571       other        carbon                NaN              NaN
# 1507      other        carbon                NaN              NaN
# 1780      other           NaN                NaN              NaN
# 1608      other         steel           aluminum              NaN
# 1559      other           NaN                NaN              NaN
# 1671      other           NaN                NaN              NaN
# 2149      other           NaN                NaN              NaN
# 295       other        carbon             carbon    sram red etap
# ...         ...           ...                ...              ...
# 1891      other           NaN                NaN              NaN
# 1923      other           NaN                NaN              NaN
# 1630      other        carbon              alloy  shimano ultegra
# 181       other        carbon              alloy  shimano ultegra
# 1479      other        carbon              alloy  shimano ultegra
# 1749      other           NaN             carbon              NaN
# 2190      other           NaN                NaN              NaN
# 1875      other      aluminum                NaN              NaN
# 67        other           NaN                NaN              NaN
# 1879      other           NaN                NaN              NaN
# 1572      other           NaN                NaN              NaN
# 301       other        carbon                NaN    sram red etap
# 619       other           NaN                NaN              NaN
# 1992      other           NaN                NaN              NaN
# 672       other        carbon                NaN              NaN
# 2178      other           NaN                NaN              NaN
# 1126      other        carbon                NaN              NaN
# 1676      other           NaN                NaN              NaN
# 1874      other      aluminum                NaN              NaN
# 1853      other        carbon              alloy              NaN
# 257       other        carbon              alloy              NaN
# 1516      other        carbon                NaN              NaN
# 2080      other           NaN                NaN              NaN
# 1642      other      chromoly                NaN     shimano sora
# 2142      other         steel              steel              NaN
# 1835      other           NaN                NaN              NaN
# 1263      other           NaN                NaN              NaN
# 1951      other           NaN           aluminum              NaN
# 1308      other         steel           aluminum              NaN
# 665       other           NaN                NaN              NaN
#
#           rd_groupset  ... crankset_groupset seatpost_material chain_groupset  \
# 2046              NaN  ...               NaN               NaN            NaN
# 1699          sram nx  ...           sram nx               NaN        sram nx
# 1825              NaN  ...               NaN               NaN            NaN
# 910               NaN  ...               NaN             alloy            NaN
# 1535    sram red etap  ...               NaN            carbon            NaN
# 2061              NaN  ...               NaN               NaN            NaN
# 1616     shimano sora  ...      shimano sora             alloy        sram x9
# 676   shimano ultegra  ...            praxis               NaN            NaN
# 1890              NaN  ...               NaN               NaN            NaN
# 2193              NaN  ...               NaN               NaN            NaN
# 1300   shimano tiagra  ...               fsa             alloy            NaN
# 2021              NaN  ...               NaN               NaN            NaN
# 510               NaN  ...               NaN               NaN            NaN
# 1625              NaN  ...               NaN             alloy            NaN
# 2170              NaN  ...               NaN               NaN            NaN
# 1972              NaN  ...               NaN               NaN            NaN
# 1766              NaN  ...               NaN               NaN            NaN
# 1346          sram gx  ...            praxis               NaN            NaN
# 1830    sram gx eagle  ...           sram xx               NaN  sram gx eagle
# 63                NaN  ...               NaN            carbon            NaN
# 2169              NaN  ...               NaN               NaN            NaN
# 2191              NaN  ...               NaN               NaN            NaN
# 571               NaN  ...               NaN               NaN            NaN
# 1507              NaN  ...               NaN            carbon            NaN
# 1780    sram gx eagle  ...           sram xx               NaN  sram gx eagle
# 1608              NaN  ...               NaN             alloy            NaN
# 1559              NaN  ...               NaN               NaN            NaN
# 1671          sram nx  ...         race face               NaN            NaN
# 2149              NaN  ...               NaN               NaN            NaN
# 295     sram red etap  ...          sram red            carbon       sram red
# ...               ...  ...               ...               ...            ...
# 1891              NaN  ...               NaN               NaN            NaN
# 1923              NaN  ...               NaN               NaN            NaN
# 1630  shimano ultegra  ...            praxis            carbon    shimano 105
# 181   shimano ultegra  ...            praxis             alloy        sram x1
# 1479  shimano ultegra  ...           sram x3            carbon            NaN
# 1749      shimano xtr  ...         race face            carbon            NaN
# 2190              NaN  ...               NaN               NaN            NaN
# 1875    sram gx eagle  ...               NaN               NaN  sram gx eagle
# 67                NaN  ...               NaN               NaN            NaN
# 1879              NaN  ...               NaN               NaN            NaN
# 1572              NaN  ...               NaN               NaN            NaN
# 301     sram red etap  ...               NaN               NaN        sram x1
# 619     sram gx eagle  ...        sram stylo               NaN  sram gx eagle
# 1992              NaN  ...               NaN               NaN            NaN
# 672        sram rival  ...        sram rival             alloy            NaN
# 2178              NaN  ...               NaN               NaN            NaN
# 1126              NaN  ...               NaN          aluminum            NaN
# 1676          sram nx  ...         race face               NaN            NaN
# 1874          sram nx  ...               NaN               NaN            NaN
# 1853         sram xO1  ...  shimano deore xt            carbon        sram x1
# 257               NaN  ...               NaN            carbon            NaN
# 1516              NaN  ...               NaN            carbon            NaN
# 2080              NaN  ...               NaN               NaN            NaN
# 1642     shimano sora  ...            praxis               NaN        sram x9
# 2142              NaN  ...               NaN               NaN            NaN
# 1835              NaN  ...               NaN               NaN            NaN
# 1263              NaN  ...               NaN               NaN            NaN
# 1951    shimano deore  ...               NaN          aluminum        sram x1
# 1308              NaN  ...               NaN             alloy            NaN
# 665               NaN  ...               NaN               NaN            NaN
#
#       shifter_groupset titanium_frame carbon_frame  carbon_handlebar  \
# 2046               NaN              0            0                 0
# 1699           sram nx              0            1                 0
# 1825               NaN              0            0                 0
# 910                NaN              0            0                 0
# 1535     sram red etap              0            1                 0
# 2061               NaN              0            0                 0
# 1616      shimano sora              0            0                 0
# 676    shimano ultegra              0            1                 0
# 1890               NaN              0            0                 0
# 2193               NaN              0            0                 0
# 1300        microshift              0            0                 0
# 2021               NaN              0            0                 0
# 510                NaN              0            1                 0
# 1625               NaN              0            0                 0
# 2170               NaN              0            0                 0
# 1972               NaN              0            0                 0
# 1766               NaN              0            0                 0
# 1346           sram gx              0            0                 0
# 1830     sram gx eagle              0            1                 0
# 63                 NaN              0            1                 0
# 2169               NaN              0            0                 0
# 2191               NaN              0            0                 0
# 571                NaN              0            0                 0
# 1507               NaN              0            1                 0
# 1780     sram gx eagle              0            1                 0
# 1608               NaN              0            0                 0
# 1559               NaN              0            0                 0
# 1671           sram nx              0            1                 0
# 2149               NaN              0            0                 0
# 295            sram x1              0            1                 1
# ...                ...            ...          ...               ...
# 1891               NaN              0            0                 0
# 1923               NaN              0            0                 0
# 1630   shimano ultegra              0            1                 0
# 181    shimano ultegra              0            0                 0
# 1479   shimano ultegra              0            1                 0
# 1749  shimano deore xt              0            1                 1
# 2190               NaN              0            0                 0
# 1875     sram gx eagle              0            0                 0
# 67                 NaN              0            1                 0
# 1879               NaN              0            0                 0
# 1572               NaN              0            0                 0
# 301      sram red etap              0            1                 0
# 619      sram gx eagle              0            1                 0
# 1992               NaN              0            0                 0
# 672         sram rival              0            1                 0
# 2178               NaN              0            0                 0
# 1126               NaN              0            0                 0
# 1676           sram nx              0            0                 0
# 1874           sram nx              0            0                 0
# 1853          sram xO1              0            1                 0
# 257                NaN              0            0                 0
# 1516               NaN              0            1                 0
# 2080               NaN              0            0                 0
# 1642      shimano sora              0            0                 0
# 2142               NaN              0            0                 0
# 1835               NaN              0            0                 0
# 1263               NaN              0            0                 0
# 1951     shimano deore              0            0                 0
# 1308               NaN              0            0                 0
# 665                NaN              0            1                 0
#
#       carbon_crankset  carbon_seatpost  nonstandard_fork
# 2046                0                0                 0
# 1699                0                0                 0
# 1825                0                0                 0
# 910                 0                0                 1
# 1535                0                1                 0
# 2061                0                0                 1
# 1616                0                0                 0
# 676                 0                0                 0
# 1890                0                0                 0
# 2193                0                0                 1
# 1300                0                0                 1
# 2021                0                0                 0
# 510                 0                0                 0
# 1625                0                0                 1
# 2170                0                0                 1
# 1972                0                0                 0
# 1766                0                0                 0
# 1346                0                0                 0
# 1830                0                0                 0
# 63                  0                1                 0
# 2169                0                0                 1
# 2191                0                0                 0
# 571                 0                0                 0
# 1507                0                1                 0
# 1780                0                0                 0
# 1608                0                0                 1
# 1559                0                0                 0
# 1671                0                0                 0
# 2149                0                0                 0
# 295                 1                1                 0
# ...               ...              ...               ...
# 1891                0                0                 0
# 1923                0                0                 0
# 1630                0                1                 0
# 181                 0                0                 0
# 1479                0                1                 0
# 1749                0                1                 0
# 2190                0                0                 0
# 1875                0                0                 0
# 67                  0                0                 0
# 1879                0                0                 0
# 1572                0                0                 0
# 301                 1                0                 0
# 619                 0                0                 0
# 1992                0                0                 0
# 672                 0                0                 0
# 2178                0                0                 0
# 1126                0                0                 0
# 1676                0                0                 0
# 1874                0                0                 0
# 1853                0                1                 0
# 257                 0                1                 0
# 1516                0                1                 0
# 2080                0                0                 0
# 1642                0                0                 1
# 2142                0                0                 1
# 1835                0                0                 0
# 1263                0                0                 0
# 1951                0                0                 0
# 1308                0                0                 1
# 665                 0                0                 0
#
# [298 rows x 22 columns]

# %% [markdown]
# #### Model Year Field

# %%
# Summary statistics
train_df.model_year.describe()

# %%
# Mode
train_df.model_year.mode()

# %%
# Counts by values
train_df.model_year.value_counts()

# %% [markdown]
# The mean is about 2018, the median is 2018, and the mode is 2019. Let's set missing values to 2018

# %%
train_df[train_df.model_year.isnull()]
